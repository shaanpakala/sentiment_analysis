# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import time
import random

# %%
# %run '0_tools.ipynb'

# %%
np_df = np.load(f'{train_vect_path}train_vect.npy')
df = pd.DataFrame(np_df)

# %%
df[1] = df.sum(axis=1)
df[1].plot.hist(bins = 100)
plt.xlabel('Number of Words')
plt.title('Frequency of Reviews for Different Lengths')
# Out:
# Text(0.5, 1.0, 'Frequency of Reviews for Different Lengths')

# %%
    df.boxplot(column = 1)
    plt.ylabel('Number of Words')
# Out:
# Text(0, 0.5, 'Number of Words')

# %%
print(f'Count of Negative ratings: {len(df[df[0]==-1])}')
print(f'Count of Neutral ratings: {len(df[df[0]==0])}')
print(f'Count of Positive ratings: {len(df[df[0]==1])}')
    

df[0].plot.hist()
plt.xlabel('Rating')
# Out:
# Count of Negative ratings: 14922
# Count of Neutral ratings: 11543
# Count of Positive ratings: 49560
# Text(0.5, 0, 'Rating')
